# %%
import numpy as np

# %%
a = np.array([1, 2, 3, 4, 5, 128], dtype=np.uint64)
print(a)
# Out:
# [  1   2   3   4   5 128]

# %%
np.arange(10, 15, 1)
# Out:
# array([10, 11, 12, 13, 14])

# %%
a = [
    [1, 2],
    [3, 4]
] 
b = a[:1]
b[0][0] = 10
b
# Out:
# [[10, 2]]

# %%
a
# Out:
# [[10, 2], [3, 4]]

# %%
s = [1, 2, 2, 3, 4, 5]
c = s[:3]
c[0] = 5
c
# Out:
# [5, 2, 2]

# %%
s
# Out:
# [1, 2, 2, 3, 4, 5]

# %%
j = np.random.randint(1, 20, size=(4, 4))
j
# Out:
# array([[19,  6,  8, 18],
#        [17,  9, 16,  3],
#        [10,  4, 12,  1],
#        [17,  7,  5,  1]], dtype=int32)
