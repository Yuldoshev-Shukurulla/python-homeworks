# %%
import numpy as np

# %%
a = np.array([1, 2, 3, 4, 5, 128], dtype=np.uint64)
a
# Out:
# array([  1,   2,   3,   4,   5, 128], dtype=uint64)

# %%
np.arange(10, 15, 1)
# Out:
# array([10, 11, 12, 13, 14])

# %%
a = [
    [1, 2],
    [3, 4]
] 
b = a[:1]
b[0][0] = 10
b
# Out:
# [[10, 2]]

# %%
a
# Out:
# [[10, 2], [3, 4]]

# %%
s = [1, 2, 2, 3, 4, 5]
c = s[:3]
c[0] = 5
c
# Out:
# [5, 2, 2]

# %%
s
# Out:
# [1, 2, 2, 3, 4, 5]
